# %%
import sys
#from mysql.connector import connect, Error
#try:
 #   with connect (host="localhost",user=input("root"),
  #               password=getpass(),
   #              )as connection:
    #    print(connection)
     #   except Error as e:
      #      print(e)
#!{sys.executable} -m pip install pandas
import urllib
from bs4 import BeautifulSoup
url = 'http://rodalies.gencat.cat/es/alteracions_del_servei/'
html = urllib.request.urlopen(url)
soup2 = BeautifulSoup(html)
img=soup2.find_all('img');
tags = [];
tagsi = [];

tag=soup2.find_all(class_="destacat_icones list-group-item")

#tag=sop2.fin_all()
#tag = tag.replace(',',' ')
#lis = tag.split()
#tagimg = tag.find_all('img');
#print(tagimg);
print(tag);
fich1 = open("prueba.html","w")
for i in tag:
    tags.append(i)
   # print(tags)
    #tagsi=tags.filter(lambda:"img")
    #print(tagsi[i])
    fich1.write('<head><meta http-equiv="Content-Type" content="text/html;charset=UTF-8"><style>.list-group-item{background-color:none}</style></head>')
    fich1.write(str(tags))
fich1.close();

#print(fich1);
# Out:
# [<li class="destacat_icones list-group-item">
# <div class="destacat_icones_cont">
# <img alt="R3" src="/web/resources/fwkResponsive/fpca_horaries/img/ico_r3.png"/>
# <span>24/08/2021 08:10h</span>
# <div>
# <p>Por obras de la infraestructura que realiza Adif, desde el 30 de agosto los trenes de la línea R3 con origen o destino La Garriga, iniciarán o finalizarán su recorrido en la estación de Les Franqueses del Vallès. Servicio alternativo con autobús. Más información en rodaliesdecatalunya.cat, renfe.com, app's, teléfono 900 41 00 41 o en las estaciones.</p>
# </div>
# </div>
# </li>, <li class="destacat_icones list-group-item">
# <div class="destacat_icones_cont">
# <img alt="R3" src="/web/resources/fwkResponsive/fpca_horaries/img/ico_r3.png"/>
# <span>14/06/2021 17:42h</span>
# <div>
# <p>A la llegada a Francia, en los controles previstos gestionados por las autoridades francesas, será obligatorio presentar una prueba PCR, de antígenos o de vacunación.</p>
# </div>
# </div>
# </li>, <li class="destacat_icones list-group-item">
# <div class="destacat_icones_cont">
# <img alt="R11" src="/web/resources/fwkResponsive/fpca_horaries/img/ico_r11.png"/>
# <span>14/06/2021 17:41h</span>
# <div>
# <p>A la llegada a Francia, en los controles previstos gestionados por las autoridades francesas, será obligatorio presentar una prueba PCR, de antígenos o de vacunación.</p>
# </div>
# </div>
# </li>, <li class="destacat_icones list-group-item">
# <div class="destacat_icones_cont">
# <img alt="RT1" src="/web/resources/fwkResponsive/fpca_horaries/img/ico_rt1.png"/>
# <span>25/03/2020 20:14h</span>
# <div>
# <p>Durante el período de reducción esta linea no prestará servicio. Disponen de los trenes de las líneas R14-R15-R16 para desplazarse entre Tarragona, Vila-seca y Reus.</p>
# </div>
# </div>
# </li>]
# /web/resources/fwkResponsive/fpca_capcalera/img/gencat-nuevo-completo-w.svg
# /web/resources/fwkResponsive/fpca_capcalera/img/contacte-b.svg
# /web/resources/fwkResponsive/fpca_capcalera/img/idioma-b.svg
# /web/resources/fwkResponsive/fpca_capcalera/img/chevron-down-small-w.svg
# /web/resources/fwkResponsive/fpca_capcalera/img/chevron-down-thin-b.svg
# /web/resources/fwkResponsive/fpca_capcalera/img/search-w.svg
# /web/resources/fwkResponsive/fpca_capcalera/img/arrow-right-r.svg
# /web/resources/fwkResponsive/fpca_capcalera/img/arrow-right-r.svg
# /web/resources/fwkResponsive/fpca_capcalera/img/arrow-right-r.svg
# /web/resources/fwkResponsive/fpca_capcalera/img/arrow-right-r.svg
# /web/resources/fwkResponsive/fpca_capcalera/img/arrow-right-r.svg
# /web/resources/fwkResponsive/fpca_capcalera/img/arrow-right-r.svg
# /.content/00_home/07_Imatges_navegacio/1.jpg
# /web/resources/fwkResponsive/fpca_capcalera/img/arrow-right-r.svg
# /web/resources/fwkResponsive/fpca_capcalera/img/arrow-right-r.svg
# /web/resources/fwkResponsive/fpca_capcalera/img/arrow-right-r.svg
# /web/resources/fwkResponsive/fpca_capcalera/img/arrow-right-r.svg
# /web/resources/fwkResponsive/fpca_capcalera/img/arrow-right-r.svg
# /.content/00_home/07_Imatges_navegacio/2.jpg
# /web/resources/fwkResponsive/fpca_capcalera/img/arrow-right-r.svg
# /web/resources/fwkResponsive/fpca_capcalera/img/arrow-right-r.svg
# /web/resources/fwkResponsive/fpca_capcalera/img/arrow-right-r.svg
# /.content/00_home/07_Imatges_navegacio/3.jpg
# /web/resources/fwkResponsive/fpca_capcalera/img/arrow-right-r.svg
# /web/resources/fwkResponsive/fpca_capcalera/img/arrow-right-r.svg
# /web/resources/fwkResponsive/fpca_capcalera/img/arrow-right-r.svg
# /web/resources/fwkResponsive/fpca_capcalera/img/arrow-right-r.svg
# /web/resources/fwkResponsive/fpca_capcalera/img/arrow-right-r.svg
# /web/resources/fwkResponsive/fpca_capcalera/img/arrow-right-r.svg
# /web/resources/fwkResponsive/fpca_capcalera/img/arrow-right-r.svg
# /web/resources/fwkResponsive/fpca_capcalera/img/arrow-right-r.svg
# /web/resources/fwkResponsive/fpca_capcalera/img/arrow-right-r.svg
# /web/resources/fwkResponsive/fpca_capcalera/img/arrow-right-r.svg
# /.content/00_home/07_Imatges_navegacio/4.jpg
# /web/resources/fwkResponsive/fpca_capcalera/img/arrow-right-r.svg
# /web/resources/fwkResponsive/fpca_capcalera/img/gencat-nuevo-completo-w.svg
# /web/resources/fwkResponsive/fpca_subcapcalera/img/twitter.svg
# /web/resources/fwkResponsive/fpca_subcapcalera/img/facebook.svg
# /web/resources/fwkResponsive/fpca_subcapcalera/img/telegram.svg
# /web/resources/fwkResponsive/fpca_subcapcalera/img/whatsapp.svg
# /web/resources/fwkResponsive/fpca_subcapcalera/img/print.svg
# /web/resources/fwkResponsives/common/img/NG_ico_slider_pestanyes_left.png
# /web/resources/fwkResponsives/common/img/NG_ico_slider_pestanyes_right.png
# /web/resources/fwkResponsive/fpca_horaries/img/ico_r3.png
# /web/resources/fwkResponsive/fpca_horaries/img/ico_r3.png
# /web/resources/fwkResponsive/fpca_horaries/img/ico_r11.png
# /web/resources/fwkResponsive/fpca_horaries/img/ico_rt1.png
# /web/resources/fwkResponsives/common/img/NG_ico_twitter.png_196546587.png
# /web/resources/fwkResponsives/common/img/NG_ico_compartir.png_196546587.png
# /web/resources/fwkResponsives/common/img/logo_generalitat_gris.png_679097835.png
# /web/resources/fwkResponsives/common/img/logo_generalitat_gris.png_679097835.png
